# %% [markdown]
# # Flipkart Product Data Analysis

# %% [markdown]
# ## 1. Product Count by Category

# %%
from IPython.display import Image
Image(filename='../visuals/01_category_counts.png')

# %% [raw]
# Insight:
# Most products are concentrated in a few categories, indicating that Flipkart focuses heavily on certain product segments. This suggests uneven distribution and potential market dominance in specific categories.

# %% [markdown]
# ## 2. Average Discount % by Category

# %%
Image(filename='../visuals/02_discount_by_category.png')

# %% [raw]
# Insight:
# Certain product categories offer significantly higher discounts (above 40%), indicating aggressive pricing strategies. This may be used to attract more customers in highly competitive categories.

# %% [markdown]
# ## 3. Price & Discount Distribution

# %%
Image(filename='../visuals/03_price_discount_dist.png')

# %% [raw]
# Insight:
# Most products fall within lower to mid price ranges, while discount percentages vary widely. This shows that Flipkart caters mainly to budget-conscious customers while offering diverse discount strategies.

# %% [markdown]
# ## 4. Product Rating Distribution

# %%
Image(filename='../visuals/04_rating_dist.png')

# %% [raw]
# Insight:
# The majority of products have ratings between 3.5 and 4.5, indicating generally positive customer feedback. Very few products have extremely low ratings.

# %% [markdown]
# ## 5. Price Distribution by Category (Box Plot)

# %%
Image(filename='../visuals/05_price_by_category_box.png')

# %% [markdown]
# ## 6. Correlation Heatmap

# %%
Image(filename='../visuals/06_correlation_heatmap.png')

# %% [raw]
# Insight:
# Retail price and discounted price show strong positive correlation, while discount percentage has weak correlation with ratings. This indicates that discounts do not strongly influence customer satisfaction.

# %% [markdown]
# ## 7. Price Segment Distribution

# %%
Image(filename='../visuals/07_price_segment_pie.png')

# %% [markdown]
# Insight:
# Most products belong to budget and mid-range price segments, showing that Flipkart primarily targets price-sensitive customers.

# %% [markdown]
# ## 8. Discount vs Rating Scatter Plot

# %%
Image(filename='../visuals/08_discount_vs_rating.png')

# %% [raw]
# Insight:
# There is no strong relationship between discount percentage and product ratings, suggesting that higher discounts do not necessarily lead to better customer satisfaction.

# %% [raw]
# Conclusion:
# Through exploratory data analysis, we observed that Flipkart’s product distribution is heavily focused on budget-friendly items. Discounts vary across categories but do not significantly impact ratings. Customer satisfaction remains generally high, indicating consistent product quality across the platform.
